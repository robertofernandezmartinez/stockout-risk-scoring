# %%
import pandas as pd
import cloudpickle
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

print("🔁 Loading data...")
project_path = '/Users/rober/retail-stockout-risk-scoring/'

name_X = 'X_balanced.pickle'
name_y = 'y_balanced.pickle'

X = pd.read_pickle(project_path + '/02_Data/03_Working/' + name_X)
y = pd.read_pickle(project_path + '/02_Data/03_Working/' + name_y)

# Basic split
X = df.drop("stockout_14d", axis=1)
y = df["stockout_14d"]

cat_features = X.select_dtypes(include=["object"]).columns.tolist()
num_features = X.select_dtypes(exclude=["object"]).columns.tolist()

preprocess = ColumnTransformer(
    transformers=[
        ("num", "passthrough", num_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
    ]
)

print("⚙️ Training quick model...")
model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    subsample=0.8,
    random_state=42
)

pipeline_best = Pipeline(steps=[
    ("pre", preprocess),
    ("model", model)
])

pipeline_best.fit(X, y)

print("💾 Exporting...")
with open("pipe_execution.pkl", "wb") as f:
    cloudpickle.dump(pipeline_best, f)

print("🎉 Model re-trained and saved as pipe_execution.pkl!")
# Out:
# 🔁 Loading data...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 16
#      13 name_X = 'X_balanced.pickle'
#      14 name_y = 'y_balanced.pickle'
# ---> 16 X = pd.read_pickle(project_path + '/02_Data/03_Working/' + name_X)
#      17 y = pd.read_pickle(project_path + '/02_Data/03_Working/' + name_y)
#      19 # Basic split
#
# File ~/opt/miniconda3/envs/ml310/lib/python3.10/site-packages/pandas/io/pickle.py:189, in read_pickle(filepath_or_buffer, compression, storage_options)
#     125 """
#     126 Load pickled pandas object (or any object) from file.
#     127
#    (...)
#     186 4    4    9
#     187 """
#     188 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 189 with get_handle(
#     190     filepath_or_buffer,
#     191     "rb",
#     192     compression=compression,
#     193     is_text=False,
# ...

# %%
df
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      2022-01-01     S001      P0001    Groceries  North              231
# 1      2022-01-01     S001      P0002         Toys  South              204
# 2      2022-01-01     S001      P0003         Toys   West              102
# 3      2022-01-01     S001      P0004         Toys  North              469
# 4      2022-01-01     S001      P0005  Electronics   East              166
# ...           ...      ...        ...          ...    ...              ...
# 73095  2024-01-01     S005      P0016    Furniture   East               96
# 73096  2024-01-01     S005      P0017         Toys  North              313
# 73097  2024-01-01     S005      P0018     Clothing   West              278
# 73098  2024-01-01     S005      P0019         Toys   East              374
# 73099  2024-01-01     S005      P0020    Groceries   East              117
#
# ...
